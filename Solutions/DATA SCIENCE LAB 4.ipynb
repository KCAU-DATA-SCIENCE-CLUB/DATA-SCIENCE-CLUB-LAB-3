# %%
#Importing all required modules
import pandas as pd
import names
from faker import Faker
#Creating an object fake from class Faker
#This acts as a setup for the required task hence in first cell
fake = Faker()

# %%
#Reading and storing the csv file in a variable df
df = pd.read_csv('Redcross data/KCAU RedCross Ballot 2024 (Responses) - Form Responses 1.csv')

# %%
#Displaying the first five rows 
df.head()
# Out:
#             Timestamp Registration No.    Chair-person Deputy chair-person  \
# 0  6/13/2024 15:13:00         21/05213  William Odundo         BETTY KADZO
# 1  6/13/2024 15:13:51         19/01428  William Odundo    Winscovia Mmbone
# 2  6/13/2024 15:19:14         22/05032  William Odundo         BETTY KADZO
# 3  6/13/2024 15:21:46         23/03751  William Odundo         BETTY KADZO
# 4  6/13/2024 15:24:03         23/06066  William Odundo    Winscovia Mmbone
#
#       Finance Secretary           Secretary Chief First Aider
# 0          Gichigi Mary  Amaya Hellen Olesi    Joshua Onyango
# 1          Gichigi Mary  Amaya Hellen Olesi    Joshua Onyango
# 2  Marylyn Waihiga Mugo       Mercy Gitenya    Joshua Onyango
# 3          Gichigi Mary  Amaya Hellen Olesi    Joshua Onyango
# 4  Marylyn Waihiga Mugo  Amaya Hellen Olesi    Joshua Onyango

# %%
#Answering Question 1(List all the records)

# %%
#First method
df
# Out:
#              Timestamp Registration No.    Chair-person Deputy chair-person  \
# 0   6/13/2024 15:13:00         21/05213  William Odundo         BETTY KADZO
# 1   6/13/2024 15:13:51         19/01428  William Odundo    Winscovia Mmbone
# 2   6/13/2024 15:19:14         22/05032  William Odundo         BETTY KADZO
# 3   6/13/2024 15:21:46         23/03751  William Odundo         BETTY KADZO
# 4   6/13/2024 15:24:03         23/06066  William Odundo    Winscovia Mmbone
# 5   6/13/2024 15:32:09         22/08108  William Odundo         BETTY KADZO
# 6   6/13/2024 15:33:12         22/09127  William Odundo         BETTY KADZO
# 7   6/13/2024 15:33:26         21/07051  William Odundo         BETTY KADZO
# 8   6/13/2024 15:33:38         22/04778  William Odundo         BETTY KADZO
# 9   6/13/2024 15:35:20         23/07797  William Odundo    Winscovia Mmbone
# 10  6/13/2024 15:39:08         22/06197  William Odundo    Winscovia Mmbone
# ...

# %%
#Second method
display(df)
# Out:
#              Timestamp Registration No.    Chair-person Deputy chair-person  \
# 0   6/13/2024 15:13:00         21/05213  William Odundo         BETTY KADZO
# 1   6/13/2024 15:13:51         19/01428  William Odundo    Winscovia Mmbone
# 2   6/13/2024 15:19:14         22/05032  William Odundo         BETTY KADZO
# 3   6/13/2024 15:21:46         23/03751  William Odundo         BETTY KADZO
# 4   6/13/2024 15:24:03         23/06066  William Odundo    Winscovia Mmbone
# 5   6/13/2024 15:32:09         22/08108  William Odundo         BETTY KADZO
# 6   6/13/2024 15:33:12         22/09127  William Odundo         BETTY KADZO
# 7   6/13/2024 15:33:26         21/07051  William Odundo         BETTY KADZO
# 8   6/13/2024 15:33:38         22/04778  William Odundo         BETTY KADZO
# 9   6/13/2024 15:35:20         23/07797  William Odundo    Winscovia Mmbone
# 10  6/13/2024 15:39:08         22/06197  William Odundo    Winscovia Mmbone
# ...

# %%
#Answering Question 2 and 3
#2. How many columns present in the dataset?
#3. How many rows present in the dataset?

# %%
df.info()
#Entries represent rows hence there are 43 rows
#There are also 7 columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Timestamp            43 non-null     object
#  1   Registration No.     43 non-null     object
#  2   Chair-person         43 non-null     object
#  3   Deputy chair-person  43 non-null     object
#  4   Finance Secretary    43 non-null     object
#  5   Secretary            43 non-null     object
#  6   Chief First Aider    43 non-null     object
# dtypes: object(7)
# memory usage: 2.5+ KB

# %%
#Answering Question 4(Check if any of the columns contains missing value(s))

# %%
df.isnull().any()
#Since it the output is false for all the columns, there are no missing value(s)
# Out:
# Timestamp              False
# Registration No.       False
# Chair-person           False
# Deputy chair-person    False
# Finance Secretary      False
# Secretary              False
# Chief First Aider      False
# dtype: bool

# %%
#Answering Question 5(Account for all the records that are missing)]
#There are no missing values in the dataset as proved in Question 4

# %%
#Answering Question 6(Change the name Timestamp to Date log.)

# %%
df = df.rename(columns={'Timestamp':'Date_log'})

# %%
#Checking to ensure it was renamed
df.head()
# Out:
#              Date_log Registration No.    Chair-person Deputy chair-person  \
# 0  6/13/2024 15:13:00         21/05213  William Odundo         BETTY KADZO
# 1  6/13/2024 15:13:51         19/01428  William Odundo    Winscovia Mmbone
# 2  6/13/2024 15:19:14         22/05032  William Odundo         BETTY KADZO
# 3  6/13/2024 15:21:46         23/03751  William Odundo         BETTY KADZO
# 4  6/13/2024 15:24:03         23/06066  William Odundo    Winscovia Mmbone
#
#       Finance Secretary           Secretary Chief First Aider
# 0          Gichigi Mary  Amaya Hellen Olesi    Joshua Onyango
# 1          Gichigi Mary  Amaya Hellen Olesi    Joshua Onyango
# 2  Marylyn Waihiga Mugo       Mercy Gitenya    Joshua Onyango
# 3          Gichigi Mary  Amaya Hellen Olesi    Joshua Onyango
# 4  Marylyn Waihiga Mugo  Amaya Hellen Olesi    Joshua Onyango

# %%
#Answering Question 7 and 8

# %%
#First method is using the names module

# %%
#Testing the code to ensure the logics are correct
#Generating 43 random full names
#Creating an empty list
full_names = []
#Using a while loop to add generated names into the list
while len(full_names) < 43 :
    name = names.get_full_name() #Generates the name
    full_names.append(name) #Adds the name to the list
    
print(full_names)
# Out:
# ['Richard Wages', 'Elton Anderson', 'Alison Hargis', 'Mary Burroughs', 'Robert Betts', 'Rafael Jorgensen', 'Claire Mcdonald', 'Charlotte Walls', 'Ronald Spaulding', 'Kari Hutsell', 'Sharon Whiteman', 'Ila Pegues', 'Joanne Brown', 'Anne Mitchell', 'Robert Summa', 'John Waller', 'William Henderlite', 'Michael Duke', 'Kayla Hood', 'Leslie White', 'Kevin Olson', 'Anne Baggesen', 'Ophelia Jessop', 'Chris Brewer', 'Hazel Callahan', 'Thomas Williams', 'Charles Reed', 'Peggy Travis', 'Judith Putt', 'Lula Hall', 'Robert Palma', 'Laci Wilson', 'Antonio Lucas', 'Ashley Tracy', 'Jerry Fonte', 'Eileen Ferebee', 'Michael Houser', 'Kelly Levy', 'Wendy Bates', 'Nicole Demello', 'Paul Hart', 'Carmen Barry', 'Alexander Hilderbrandt']

# %%
#Crearing a new dataframe as a copy of the original to test this method
method1_df = df.copy()
#Checking that the dataframe is as expected
method1_df.head()
# Out:
#              Date_log Registration No.    Chair-person Deputy chair-person  \
# 0  6/13/2024 15:13:00         21/05213  William Odundo         BETTY KADZO
# 1  6/13/2024 15:13:51         19/01428  William Odundo    Winscovia Mmbone
# 2  6/13/2024 15:19:14         22/05032  William Odundo         BETTY KADZO
# 3  6/13/2024 15:21:46         23/03751  William Odundo         BETTY KADZO
# 4  6/13/2024 15:24:03         23/06066  William Odundo    Winscovia Mmbone
#
#       Finance Secretary           Secretary Chief First Aider
# 0          Gichigi Mary  Amaya Hellen Olesi    Joshua Onyango
# 1          Gichigi Mary  Amaya Hellen Olesi    Joshua Onyango
# 2  Marylyn Waihiga Mugo       Mercy Gitenya    Joshua Onyango
# 3          Gichigi Mary  Amaya Hellen Olesi    Joshua Onyango
# 4  Marylyn Waihiga Mugo  Amaya Hellen Olesi    Joshua Onyango

# %%
#Implementing the code
#Creating an empty list
members1 = []
#Using a while loop to add generated names into the list
while len(members1) < 43 :
    member1 = names.get_full_name() #Generates the name
    members1.append(member1) #Adds the name to the list

# %%
#Creating a new column Members and inserting the list members1 in the new column
method1_df['Members'] = members1

# %%
method1_df
# Out:
#               Date_log Registration No.    Chair-person Deputy chair-person  \
# 0   6/13/2024 15:13:00         21/05213  William Odundo         BETTY KADZO
# 1   6/13/2024 15:13:51         19/01428  William Odundo    Winscovia Mmbone
# 2   6/13/2024 15:19:14         22/05032  William Odundo         BETTY KADZO
# 3   6/13/2024 15:21:46         23/03751  William Odundo         BETTY KADZO
# 4   6/13/2024 15:24:03         23/06066  William Odundo    Winscovia Mmbone
# 5   6/13/2024 15:32:09         22/08108  William Odundo         BETTY KADZO
# 6   6/13/2024 15:33:12         22/09127  William Odundo         BETTY KADZO
# 7   6/13/2024 15:33:26         21/07051  William Odundo         BETTY KADZO
# 8   6/13/2024 15:33:38         22/04778  William Odundo         BETTY KADZO
# 9   6/13/2024 15:35:20         23/07797  William Odundo    Winscovia Mmbone
# 10  6/13/2024 15:39:08         22/06197  William Odundo    Winscovia Mmbone
# ...

# %%
#Second method is using the Faker class from faker module

# %%
#Testing the code to ensure the logics are correct
#Creating an object fake from class Faker (Just emphasis)
fake = Faker()

#Creating an empty list
names2 = []
#Using a while loop to add generated names into the list
while len(names2) < 43 :
    name2 = fake.name() #Generates the name
    names2.append(name2) #Adds the name to the list

print(names2)
# Out:
# ['Brandon Medina', 'Robert Lyons', 'Brandon Lopez', 'Jason Mcdonald', 'Megan Becker', 'Cristina Sharp', 'Deborah Fernandez', 'Melissa Hopkins', 'Amanda White', 'Frederick Carter', 'Heather Villanueva', 'Wendy Jacobs', 'Patricia Harris', 'Laura Jackson', 'Diane Wagner', 'Heather Bell', 'Michael Franklin', 'Alexander Saunders MD', 'Kevin Norris', 'Kelsey Stein', 'Amanda Garrison', 'Rebecca Shields', 'Robert Martinez', 'Stephanie Espinoza', 'Carla Maldonado', 'James Brown', 'Shelby Gonzalez', 'Dr. Robert Thompson', 'Patricia Novak', 'Claudia Lewis', 'Ryan Stevens', 'Mitchell Underwood', 'Barbara Munoz', 'Todd Thompson', 'Denise Taylor', 'Dawn Peterson', 'Nancy Harvey', 'Kevin Cain', 'Tara Allen', 'Patricia Watkins', 'Christopher Gonzalez', 'Samantha Miller', 'Amanda Vega']

# %%
#Crearing a new dataframe variable to test this method
method2_df = df.copy()
#Checking that the dataframe is as expected
method2_df.head()
# Out:
#              Date_log Registration No.    Chair-person Deputy chair-person  \
# 0  6/13/2024 15:13:00         21/05213  William Odundo         BETTY KADZO
# 1  6/13/2024 15:13:51         19/01428  William Odundo    Winscovia Mmbone
# 2  6/13/2024 15:19:14         22/05032  William Odundo         BETTY KADZO
# 3  6/13/2024 15:21:46         23/03751  William Odundo         BETTY KADZO
# 4  6/13/2024 15:24:03         23/06066  William Odundo    Winscovia Mmbone
#
#       Finance Secretary           Secretary Chief First Aider
# 0          Gichigi Mary  Amaya Hellen Olesi    Joshua Onyango
# 1          Gichigi Mary  Amaya Hellen Olesi    Joshua Onyango
# 2  Marylyn Waihiga Mugo       Mercy Gitenya    Joshua Onyango
# 3          Gichigi Mary  Amaya Hellen Olesi    Joshua Onyango
# 4  Marylyn Waihiga Mugo  Amaya Hellen Olesi    Joshua Onyango

# %%
#Implementing the code
#Creating an empty list
members2 = []
#Using a while loop to add generated names into the list
while len(members2) < 43 :
    member2 = fake.name() #Generates the name
    members2.append(member2) #Adds the name to the list

# %%
#Creating a new column Members and inserting the list members in the new column
method2_df['Members'] = members2

# %%
method2_df
# Out:
#               Date_log Registration No.    Chair-person Deputy chair-person  \
# 0   6/13/2024 15:13:00         21/05213  William Odundo         BETTY KADZO
# 1   6/13/2024 15:13:51         19/01428  William Odundo    Winscovia Mmbone
# 2   6/13/2024 15:19:14         22/05032  William Odundo         BETTY KADZO
# 3   6/13/2024 15:21:46         23/03751  William Odundo         BETTY KADZO
# 4   6/13/2024 15:24:03         23/06066  William Odundo    Winscovia Mmbone
# 5   6/13/2024 15:32:09         22/08108  William Odundo         BETTY KADZO
# 6   6/13/2024 15:33:12         22/09127  William Odundo         BETTY KADZO
# 7   6/13/2024 15:33:26         21/07051  William Odundo         BETTY KADZO
# 8   6/13/2024 15:33:38         22/04778  William Odundo         BETTY KADZO
# 9   6/13/2024 15:35:20         23/07797  William Odundo    Winscovia Mmbone
# 10  6/13/2024 15:39:08         22/06197  William Odundo    Winscovia Mmbone
# ...
